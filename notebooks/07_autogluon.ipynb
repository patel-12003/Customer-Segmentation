# %% [markdown]
# # 07 — AutoGluon AutoML
#
# **Goal**: Train AutoGluon TabularPredictor and compare against manually trained models.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from src.config_manager import ConfigurationManager
from src.constants import CLEAN_DATA_FILE
from src.models.autogluon_trainer import AutoGluonTrainer

cm = ConfigurationManager()
df = pd.read_csv(CLEAN_DATA_FILE)
df.columns = [c.replace(' ', '_') for c in df.columns]

automl = AutoGluonTrainer(cm)
artifact = automl.run(df)

# %% [markdown]
# ## Leaderboard

# %%
if artifact.leaderboard is not None:
    artifact.leaderboard.head(10)
else:
    print('AutoGluon not available')

# %% [markdown]
# ## Best Model
#
# AutoGluon's best model is saved under `saved_models/autogluon/`.
#
# **Next**: `08_explainability.ipynb`
